# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando21854/WebScraper-COVID-19/blob/main/Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Web Scraper - Fernando Vargas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define URL
url = "https://www.worldometers.info/coronavirus/#countries"

# Request data from the URL
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Find the table in the HTML
table = soup.find("table", id="main_table_countries_today")

# Extract headers
column_names = [header.text.strip() for header in table.findAll("th")]

# Extract rows
data_rows = []
for row in table.findAll("tr")[1:]:
    row_data = [cell.text.strip() for cell in row.findAll("td")]
    data_rows.append(row_data)

# Create a DataFrame
covid_data = pd.DataFrame(data_rows, columns=column_names)

# Select relevant columns
covid_data = covid_data[['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical']]

# Save the data to a CSV file
covid_data.to_csv("covid19_statistics.csv", index=False)

# Display the DataFrame
covid_data
# Out:
#      Country,Other   TotalCases NewCases TotalDeaths NewDeaths TotalRecovered  \
# 0    North America  126,107,734            1,627,063              121,837,441
# 1             Asia  216,280,876   +5,027   1,543,641        +8    200,354,996
# 2           Europe  248,669,409            2,049,469              244,403,089
# 3    South America   68,509,097            1,353,868               66,440,022
# 4          Oceania   14,128,791               27,076               13,941,867
# ..             ...          ...      ...         ...       ...            ...
# 242         Total:   68,509,097            1,353,868               66,440,022
# 243         Total:   14,128,791               27,076               13,941,867
# 244         Total:   12,817,610              258,705               12,083,560
# 245         Total:          721                   15                      706
# 246         Total:  686,514,238   +5,027   6,859,837        +8    659,061,681
#
#     ActiveCases Serious,Critical
# 0     2,643,230            6,649
# 1    14,382,239           15,589
# 2     2,216,851            6,431
# 3       715,207           10,155
# 4       159,848               89
# ..          ...              ...
# 242     715,207           10,155
# 243     159,848               89
# 244     475,345              548
# 245           0                0
# 246  20,592,720           39,461
#
# [247 rows x 8 columns]

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
data = pd.read_csv("covid19_statistics.csv")

# Define labels for the hover_data
hover_labels = {'TotalCases': 'Total Cases', 'TotalDeaths': 'Total Deaths', 'TotalRecovered': 'Total Recovered',
                'ActiveCases': 'Active Cases', 'Serious,Critical': 'Serious/Critical'}

# Create a choropleth map using the 'YlOrRd' color scale
choropleth_map = px.choropleth(data, locations='Country,Other', locationmode='country names', color='TotalCases',
                                hover_name='Country,Other', range_color=[0, data['TotalCases'].max()],
                                color_continuous_scale='YlOrRd', title='COVID-19 Total Cases by Country (Conic Projection)',
                                hover_data=['TotalCases', 'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical'],
                                labels=hover_labels)

# Customize the layout
choropleth_map.update_layout(
    margin=dict(l=0, r=0, t=30, b=0),
    font=dict(size=12),
    #make the map look more realistic 
    geo=dict(projection_type="albers", showcoastlines=True)
)

# Add and set the title for the color bar
choropleth_map.update_layout(coloraxis_colorbar=dict(title='Total Cases', thickness=20, title_font=dict(size=14)))

# Display the choropleth map
choropleth_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="263338f3-e69d-4a4e-afb9-49a6a04e8c14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("263338f3-e69d-4a4e-afb9-49a6a04e8c14")) {                    Plotly.newPlot(                        "263338f3-e69d-4a4e-afb9-49a6a04e8c14",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"customdata":[["126,107,734","1,627,063","121,837,441","2,643,230","6,649"],["126,107,734","1,627,063","121,837,441","2,643,230","6,649"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Total Cases=%{customdata[0]}<br>Country,Other=%{location}<br>Total Deaths=%{customdata[1]}<br>Total Recovered=%{customdata[2]}<br>Active Cases=%{customdata[3]}<br>Serious/Critical=%{customdata[4]}<extra></extra>","hovertext":["North America","Total:"],"locationmode":"country names","locations":["North America","Total:"],"name":"126,107,734","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#EF553B"],[1.0,"#EF553B"]],"customdata":[["216,280,876","1,543,641","200,354,996","14,382,239","15,589"],["216,280,876","1,543,641","200,354,996","14,382,239","15,589"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Total Cases=%{customdata[0]}<br>Country,Other=%{location}<br>Total Deaths=%{customdata[1]}<br>Total Recovered=%{customdata[2]}<br>Active Cases=%{customdata[3]}<br>Serious/Critical=%{customdata[4]}<extra></extra>","hovertext":["Asia","Total:"],"locationmode":"country names","locations":["Asia","Total:"],"name":"216,280,876","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#00cc96"],[1.0,"#00cc96"]],"customdata":[["248,669,409","2,049,469","244,403,089","2,216,851","6,431"],["248,669,409","2,049,469","244,403,089","2,216,851","6,431"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Total Cases=%{customdata[0]}<br>Country,Other=%{location}<br>Total Deaths=%{customdata[1]}<br>Total Recovered=%{customdata[2]}<br>Active Cases=%{customdata[3]}<br>Serious/Critical=%{customdata[4]}<extra></extra>","hovertext":["Europe","Total:"],"locationmode":"country names","locations":["Europe","Total:"],"name":"248,669,409","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#ab63fa"],[1.0,"#ab63fa"]],"customdata":[["68,509,097","1,353,868","66,440,022","715,207","10,155"],["68,509,097","1,353,868","66,440,022","715,207","10,155"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Total Cases=%{customdata[0]}<br>Country,Other=%{location}<br>Total Deaths=%{customdata[1]}<br>Total Recovered=%{customdata[2]}<br>Active Cases=%{customdata[3]}<br>Serious/Critical=%{customdata[4]}<extra></extra>","hovertext":["South America","Total:"],"locationmode":"country names","locations":["South America","Total:"],"name":"68,509,097","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#FFA15A"],[1.0,"#FFA15A"]],"customdata":[["14,128,791","27,076","13,941,867","159,848","89"],["14,128,791","27,076","13,941,867","159,848","89"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Total Cases=%{customdata[0]}<br>Country,Other=%{location}<br>Total Deaths=%{customdata[1]}<br>Total Recovered=%{customdata[2]}<br>Active Cases=%{customdata[3]}<br>Serious/Critical=%{customdata[4]}<extra></extra>","hovertext":["Oceania","Total:"],"locationmode":"country names","locations":["Oceania","Total:"],"name":"14,128,791","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#19d3f3"],[1.0,"#19d3f3"]],"customdata":[["12,817,610","258,705","12,083,560","475,345","548"],["12,817,610","258,705","12,083,560","475,345","548"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Total Cases=%{customdata[0]} ...

# %% [markdown]
# ###Fernando Vargas Web Sraper
